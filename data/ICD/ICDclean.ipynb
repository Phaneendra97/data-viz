# %%
import pandas as pd
df=pd.read_csv('ICDcodes.csv',dtype='str')
df
# Out:
#       DIAGNOSIS CODE                                   LONG DESCRIPTION
# 0              001_0                     Cholera due to vibrio cholerae  \
# 1              001_1              Cholera due to vibrio cholerae el tor
# 2              001_9                               Cholera, unspecified
# 3              002_0                                      Typhoid fever
# 4              002_1                                Paratyphoid fever A
# ...              ...                                                ...
# 12162        999_8_4  Acute hemolytic transfusion reaction, incompat...
# 12163        999_8_5  Delayed hemolytic transfusion reaction, incomp...
# 12164        999_8_8                            Other infusion reaction
# 12165        999_8_9                         Other transfusion reaction
# 12166          999_9  Other and unspecified complications of medical...
#
#               SHORT DESCRIPTION
# 0      Cholera d/t vib cholerae
# 1        Cholera d/t vib el tor
# ...

# %%
def split_mc(mc: str):
    resp = mc.split("_")
    if len(resp) == 1:
      return resp[0].strip(),str("NA"), str("NA")
    elif len(resp)==2:
        return resp[0].strip(),resp[1].strip(), str("NA")
    else:
        return resp[0].strip(), resp[1].strip(), resp[2].strip()
df = df.join(pd.DataFrame(df['DIAGNOSIS CODE'].apply(split_mc).tolist(), columns=["Main Code", "CODE4", "CODE5"]))
df
# Out:
#       DIAGNOSIS CODE                                   LONG DESCRIPTION
# 0              001_0                     Cholera due to vibrio cholerae  \
# 1              001_1              Cholera due to vibrio cholerae el tor
# 2              001_9                               Cholera, unspecified
# 3              002_0                                      Typhoid fever
# 4              002_1                                Paratyphoid fever A
# ...              ...                                                ...
# 12162        999_8_4  Acute hemolytic transfusion reaction, incompat...
# 12163        999_8_5  Delayed hemolytic transfusion reaction, incomp...
# 12164        999_8_8                            Other infusion reaction
# 12165        999_8_9                         Other transfusion reaction
# 12166          999_9  Other and unspecified complications of medical...
#
#               SHORT DESCRIPTION Main Code CODE4 CODE5
# ...

# %%
def sub_ch(stream: str):
    mc=int(stream)
    if mc <= 9:
        return "Infectious and Parasitic Diseases", "Intestinal infectious diseases"
    elif mc <= 18:
        return "Infectious and Parasitic Diseases", "Tuberculosis"
    elif mc <= 27:
        return "Infectious and Parasitic Diseases", "Zoonotic bacterial diseases"
    elif mc <= 41:
        return "Infectious and Parasitic Diseases", "Other bacterial diseases"
    elif mc <= 44:
        return "Infectious and Parasitic Diseases", "Human immunodeficiency virus (HIV) infection"
    elif mc <= 49:
        return "Infectious and Parasitic Diseases", "Poliomyelitis and other non-arthropod-borne viral diseases of central nervous system"
    elif mc <= 59:
        return "Infectious and Parasitic Diseases", "Viral diseases accompanied by exanthem"
    elif mc <= 66:
        return "Infectious and Parasitic Diseases", "Arthropod-borne viral diseases"
    elif mc <= 79:
        return "Infectious and Parasitic Diseases", "Other diseases due to viruses and Chlamydiota"
    elif mc <= 88:
        return "Infectious and Parasitic Diseases", "Rickettsioses and other arthropod-borne diseases"
    elif mc <= 99:
        return "Infectious and Parasitic Diseases", "Syphilis and other venereal diseases"
    elif mc <= 104:
        return "Infectious and Parasitic Diseases", "Other spirochetal diseases"
    elif mc <= 118:
        return "Infectious and Parasitic Diseases", "Mycoses"
    elif mc <= 129:
        return "Infectious and Parasitic Diseases", "Helminthiases"
    elif mc <= 138:
        return "Infectious and Parasitic Diseases", "Other infectious and parasitic diseases"
    elif mc <= 139:
        return "Infectious and Parasitic Diseases", "Late effects of infectious and parasitic diseases"
    elif mc <= 149:
        return "Neoplasms", "Malignant neoplasm of lip, oral cavity, and pharynx"
    elif mc <= 159:
        return "Neoplasms", "Malignant neoplasm of digestive organs and peritoneum"
    elif mc <= 165:
        return "Neoplasms", "Malignant neoplasm of respiratory and intrathoracic organs"
    elif mc <= 175:
        return "Neoplasms", "Malignant neoplasm of bone, connective tissue, skin, and breast"
    elif mc <= 176:
        return "Neoplasms", "Kaposi's sarcoma"
    elif mc <= 189:
        return "Neoplasms", "Malignant neoplasm of genitourinary organs"
    elif mc <= 199:
        return "Neoplasms", "Malignant neoplasm of other and unspecified sites"
    elif mc <= 208:
        return "Neoplasms", "Malignant neoplasm of lymphatic and hematopoietic tissue"
    elif mc <= 209:
        return "Neoplasms", "Neuroendocrine tumors"
    elif mc <= 229:
        return "Neoplasms", "Benign neoplasms"
    elif mc <= 234:
        return "Neoplasms", "Carcinoma in situ"
    elif mc <= 238:
        return "Neoplasms", "Neoplasms of uncertain behavior"
    elif mc <= 239:
        return "Neoplasms", "Neoplasms of unspecified nature"
    elif mc <= 246:
        return "Endocrine, Nutritional and Metabolic Diseases, and Immunity Disorders", "Disorders of thyroid gland"
    elif mc <= 259:
        return "Endocrine, Nutritional and Metabolic Diseases, and Immunity Disorders", "Diseases of other endocrine glands"
    elif mc <= 269:
        return "Endocrine, Nutritional and Metabolic Diseases, and Immunity Disorders", "Nutritional deficiencies"
    elif mc <= 279:
        return "Endocrine, Nutritional and Metabolic Diseases, and Immunity Disorders", "Other metabolic and immunity disorders"
    elif mc <= 285:
        return "Diseases of the blood and blood-forming organs", "Anemia"
    elif mc <= 287:
        return "Diseases of the blood and blood-forming organs", "Coagulation/hemorrhagic"
    elif mc <= 289:
        return "Diseases of the blood and blood-forming organs", "Other"
    elif mc <= 299:
        return "Mental disorders", "Psychosis"
    elif mc <= 316:
        return "Mental disorders", "Neurotic disorders, personality disorders, and other nonpsychotic mental disorders"
    elif mc <= 319:
        return "Mental disorders", "Mental retardation"
    elif mc <= 326:
        return "Diseases of the nervous system and sense organs", "Inflammatory diseases of the central nervous system"
    elif mc <= 337:
        return "Diseases of the nervous system and sense organs", "Hereditary and Degenerative diseases of the central nervous system"
    elif mc <= 349:
        return "Diseases of the nervous system and sense organs", "Other disorders of the central nervous system"
    elif mc <= 359:
        return "Diseases of the nervous system and sense organs", "Disorders of the peripheral nervous system"
    elif mc <= 379:
        return "Diseases of the nervous system and sense organs", "Disorders of the eye and adnexa"
    elif mc <= 389:
        return "Diseases of the nervous system and sense organs", "Diseases of the ear and mastoid process"
    elif mc <= 392:
        return "Diseases of the circulatory system", "Acute rheumatic fever"
    elif mc <= 398:
        return "Diseases of the circulatory system", "Chronic rheumatic heart disease"
    elif mc <= 405:
        return "Diseases of the circulatory system", "Hypertensive disease"
    elif mc <= 414:
        return "Diseases of the circulatory system", "Ischemic heart disease"
    elif mc <= 417:
        return "Diseases of the circulatory system", "Diseases of pulmonary circulation"
    elif mc <= 429:
        return "Diseases of the circulatory system", "Other forms of heart disease"
    elif mc <= 438:
        return "Diseases of the circulatory system", "Cerebrovascular disease"
    elif mc <= 449:
        return "Diseases of the circulatory system", "Diseases of arteries, arterioles, and capillaries"
    elif mc <= 459:
        return "Diseases of the circulatory system", "Diseases of veins and lymphatics, and other diseases of circulatory system"
    elif mc <= 466:
        return "Diseases of the respiratory system", "Acute respiratory infections"
    elif mc <= 478:
        return "Diseases of the respiratory system", "Other diseases of the upper respiratory tract"
    elif mc <= 488:
        return "Diseases of the respiratory system", "Pneumonia and influenza"
    elif mc <= 496:
        return "Diseases of the respiratory system", "Chronic obstructive pulmonary disease and allied conditions"
    elif mc <= 508:
        return "Diseases of the respiratory system", "Pneumoconioses and other lung diseases due to external agents"
    elif mc <= 519:
        return "Diseases of the respiratory system", "Other diseases of the respiratory system"
    elif mc <= 529:
        return "Diseases of the digestive system", "Diseases of oral cavity, salivary glands, and jaws"
    elif mc <= 539:
        return "Diseases of the digestive system", "Diseases of esophagus, stomach, and duodenum"
    elif mc <= 543:
        return "Diseases of the digestive system", "Appendicitis"
    elif mc <= 553:
        return "Diseases of the digestive system", "Hernia of abdominal cavity"
    elif mc <= 558:
        return "Diseases of the digestive system", "Noninfectious enteritis and colitis"
    elif mc <= 569:
        return "Diseases of the digestive system", "Other diseases of intestines and peritoneum"
    elif mc <= 579:
        return "Diseases of the digestive system", "Other diseases of the digestive system"
    elif mc <= 599:
        return "Diseases of the genitourinary system", "Diseases of the urinary system"
    elif mc <= 608:
        return "Diseases of the genitourinary system", "Diseases of male genital organs"
    elif mc <= 612:
        return "Diseases of the genitourinary system", "Disorders Of Breast"
    elif mc <= 616:
        return "Diseases of the genitourinary system", "Inflammatory Disease Of Female Pelvic Organs"
    elif mc <= 629:
        return "Diseases of the genitourinary system", "Other disorders of female genital tract"
    elif mc <= 639:
        return "Complications of pregnancy, childbirth, and the puerperium", "Ectopic and molar pregnancy"
    elif mc <= 649:
        return "Complications of pregnancy, childbirth, and the puerperium", "Other pregnancy with abortive outcome"
    elif mc <= 659:
        return "Complications of pregnancy, childbirth, and the puerperium", "Complications mainly related to pregnancy"
    elif mc <= 669:
        return "Complications of pregnancy, childbirth, and the puerperium", "Normal delivery, and other indications for care in pregnancy, labor, and delivery"
    elif mc <= 677:
        return "Complications of pregnancy, childbirth, and the puerperium", "Complications occurring mainly in the course of labor and delivery"
    elif mc <= 679:
        return "Complications of pregnancy, childbirth, and the puerperium", "Complications of the puerperium"
    elif mc <= 709:
        return "Diseases of the skin and subcutaneous tissue", "Other diseases of skin and subcutaneous tissue"
    elif mc <= 719:
        return "Diseases of the musculoskeletal system and connective tissue", "Arthropathies and related disorders"
    elif mc <= 724:
        return "Diseases of the musculoskeletal system and connective tissue", "Dorsopathies"
    elif mc <= 729:
        return "Diseases of the musculoskeletal system and connective tissue", "Rheumatism, excluding the back"
    elif mc <= 739:
        return "Diseases of the musculoskeletal system and connective tissue", "Osteopathies, chondropathies, and acquired musculoskeletal deformities"
    elif mc <= 742:
        return "Diseases of the musculoskeletal system and connective tissue", "Nervous system"
    elif mc <= 744:
        return "Diseases of the musculoskeletal system and connective tissue", "Eye, ear, face and neck"
    elif mc <= 747:
        return "Diseases of the musculoskeletal system and connective tissue", "Circulatory system"
    elif mc <= 748:
        return "Diseases of the musculoskeletal system and connective tissue", "Respiratory system"
    elif mc <= 751:
        return "Diseases of the musculoskeletal system and connective tissue", "Digestive system"
    elif mc <= 752:
        return "Diseases of the musculoskeletal system and connective tissue", "Genital organs"
    elif mc <= 753:
        return "Diseases of the musculoskeletal system and connective tissue", "Urinary system"
    elif mc <= 756:
        return "Diseases of the musculoskeletal system and connective tissue", "Musculoskeletal system"
    elif mc <= 757:
        return "Diseases of the musculoskeletal system and connective tissue", "Integument"
    elif mc <= 758:
        return "Diseases of the musculoskeletal system and connective tissue", "Chromosomal anomalies"
    elif mc <= 759:
        return "Diseases of the musculoskeletal system and connective tissue", "Other"
    elif mc <= 763:
        return "Certain conditions originating in the perinatal period", "Maternal causes of perinatal morbidity and mortality"
    elif mc <= 779:
        return "Certain conditions originating in the perinatal period", "Other conditions originating in the perinatal period"
    elif mc <= 789:
        return "Symptoms, signs, and ill-defined conditions", "Symptoms"
    elif mc <= 796:
        return "Symptoms, signs, and ill-defined conditions", "Nonspecific abnormal findings"
    elif mc <= 799:
        return "Symptoms, signs, and ill-defined conditions", "Ill-defined and unknown causes of morbidity and mortality"
    elif mc <= 809:
        return "Injury and poisoning", "Fracture of neck and trunk"
    elif mc <= 819:
        return "Injury and poisoning", "Fracture of upper limb"
    elif mc <= 829:
        return "Injury and poisoning", "Fracture of lower limb"
    elif mc <= 839:
        return "Injury and poisoning", "Dislocation"
    elif mc <= 848:
        return "Injury and poisoning", "Sprains and strains of joints and adjacent muscles"
    elif mc <= 854:
        return "Injury and poisoning", "Intracranial injury, excluding those with skull fracture"
    elif mc <= 869:
        return "Injury and poisoning", "Internal injury of thorax, abdomen, and pelvis"
    elif mc <= 879:
        return "Injury and poisoning", "Open wound of head, neck, and trunk"
    elif mc <= 887:
        return "Injury and poisoning", "Open wound of upper limb"
    elif mc <= 897:
        return "Injury and poisoning", "Open wound of lower limb"
    elif mc <= 904:
        return "Injury and poisoning", "Injury to blood vessels"
    elif mc <= 909:
        return "Injury and poisoning", "Late effects of injuries, poisonings, toxic effects, and other external causes"
    elif mc <= 919:
        return "Injury and poisoning", "Superficial injury"
    elif mc <= 924:
        return "Injury and poisoning", "Contusion with intact skin surface"
    elif mc <= 929:
        return "Injury and poisoning", "Crushing injury"
    elif mc <= 939:
        return "Injury and poisoning", "Effects of foreign body entering through Body orifice"
    elif mc <= 949:
        return "Injury and poisoning", "Burns"
    elif mc <= 957:
        return "Injury and poisoning", "Injury to nerves and spinal cord"
    elif mc <= 959:
        return "Injury and poisoning", "Certain traumatic complications and unspecified injuries"
    elif mc <= 979:
        return "Injury and poisoning", "Poisoning by drugs, medicinal and biological substances"
    elif mc <= 989:
        return "Injury and poisoning", "Toxic effects of substances chiefly nonmedicinal as to source"
    elif mc <= 995:
        return "Injury and poisoning", "Other and unspecified effects of external causes"
    elif mc <= 999:
        return "Injury and poisoning", "Complications of surgical and medical care, not elsewhere classified"
    else:
        return "", ""



Finaldf = df.join(pd.DataFrame(df["Main Code"].apply(sub_ch).tolist(), columns=["Chapter", "Subchapter"]))
Finaldf
# Out:
#       DIAGNOSIS CODE                                   LONG DESCRIPTION
# 0              001_0                     Cholera due to vibrio cholerae  \
# 1              001_1              Cholera due to vibrio cholerae el tor
# 2              001_9                               Cholera, unspecified
# 3              002_0                                      Typhoid fever
# 4              002_1                                Paratyphoid fever A
# ...              ...                                                ...
# 12162        999_8_4  Acute hemolytic transfusion reaction, incompat...
# 12163        999_8_5  Delayed hemolytic transfusion reaction, incomp...
# 12164        999_8_8                            Other infusion reaction
# 12165        999_8_9                         Other transfusion reaction
# 12166          999_9  Other and unspecified complications of medical...
#
#               SHORT DESCRIPTION Main Code CODE4 CODE5
# ...

# %%
import pandas as pd
dd=pd.read_csv('ICDcodesdata.csv',dtype='str')
dg=dd.groupby("name3").first().reset_index()

# %%
dg=dg[pd.to_numeric(dg['name3'], errors='coerce').notnull()]
dg = dg.rename(columns={'name3': 'Main Code', 'des': 'MainDes'})
Finaldf=pd.merge(Finaldf, dg, on='Main Code')
Finaldf.to_csv('ICDcodes_clean.csv',index=False)
